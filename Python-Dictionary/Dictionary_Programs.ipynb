# %% [markdown]
# ####1. Given a dictionary my_dict = {'a': 10, 'b': 20, 'c': 30}, how can you access the value associated with key 'b'? Write a Python program to achieve this.

# %%
my_dict = {'a': 10, 'b': 20, 'c': 30}
value = my_dict['b']
print("Value of key b : ", value)
# Out:
# Value of key b :  20

# %% [markdown]
# ####2. Suppose you have a dictionary my_dict = {'name': 'John', 'age': 25, 'city': 'New York'}, how can you update the value of 'age' to 30? Write a Python program to achieve this.

# %%
my_dict = {'name': 'John', 'age': 25, 'city': 'New York'}
my_dict['age']= 30
print(my_dict)
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York'}

# %% [markdown]
# ####3. Given a dictionary my_dict = {'a': 10, 'b': 20, 'c': 30}, how can you remove the key 'b'? Write a Python program to achieve this.

# %%
my_dict = {'a': 10, 'b': 20, 'c': 30}
my_dict.pop('b')
print(my_dict)
# Out:
# {'a': 10, 'c': 30}

# %% [markdown]
# ####4. Suppose you have a dictionary my_dict = {'name': 'Alice', 'age': 30}, how can you add a new key-value pair 'city': 'London'? Write a Python program to achieve this.

# %%
my_dict = {'name': 'Alice', 'age': 30}
my_dict['city'] = 'London'
print(my_dict)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'London'}

# %% [markdown]
# ####5. Given a dictionary my_dict = {'x': 1, 'y': 2, 'z': 3}, how can you get a list of all keys? Write a Python program to achieve this.

# %%
my_dict = {'x': 1, 'y': 2, 'z': 3}
keys_list = list(my_dict.keys())
print("Keys : ", keys_list)
# Out:
# Keys :  ['x', 'y', 'z']

# %% [markdown]
# ####6. Suppose you have a dictionary my_dict = {'x': 1, 'y': 2, 'z': 3}, how can you get a list of all values? Write a Python program to achieve this.

# %%
my_dict = {'x': 1, 'y': 2, 'z': 3}
values_list = list(my_dict.values())
print("Values: ", values_list)
# Out:
# Values:  [1, 2, 3]

# %% [markdown]
# ####7. Given a dictionary my_dict = {'a': 10, 'b': 20, 'c': 30}, how can you check if key 'b' exists? Write a Python program to achieve this.

# %%
my_dict = {'a': 10, 'b': 20, 'c': 30}
if 'b' in my_dict:
  print("Key 'b' exists")
else:
  print("Key 'b' does not exist")
# Out:
# Key 'b' exists

# %% [markdown]
# ####8. Suppose you have a dictionary my_dict = {'a': 10, 'b': 20, 'c': 30}, how can you iterate over its key-value pairs? Write a Python program to achieve this.

# %%
my_dict = {'a': 10, 'b': 20, 'c': 30}
for key, value in my_dict.items():
  print(key, ":", value)
# Out:
# a : 10
# b : 20
# c : 30

# %% [markdown]
# ####9. Given a dictionary my_dict = {'x': 1, 'y': 2, 'z': 3}, how can you clear all elements from the dictionary? Write a Python program to achieve this.

# %%
my_dict = {'x': 1, 'y': 2, 'z': 3}
my_dict.clear()
print(my_dict)
# Out:
# {}

# %% [markdown]
# ####10. Suppose you have a dictionary my_dict = {'name': 'Alice', 'age': 30}, how can you find its length? Write a Python program to achieve this.

# %%
my_dict = {'name': 'Alice', 'age': 30}
length = len(my_dict)
print("Length of dictionary : ", length)
# Out:
# Length of dictionary :  2

# %% [markdown]
# ####11. Given two dictionaries dict1 = {'a': 1, 'b': 2} and dict2 = {'c': 3, 'd': 4}, how can you merge them? Write a Python program to achieve this.

# %%
 dict1 = {'a': 1, 'b': 2}
 dict2 = {'c': 3, 'd': 4}
 dict1.update(dict2)
 print(dict1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# ####12. Suppose you have a dictionary my_dict = {'name': 'John', 'age': 25}, how can you copy it to another dictionary? Write a Python program to achieve this.

# %%
my_dict = {'name': 'John', 'age': 25}
copy_list = my_dict.copy()
print(copy_list)
# Out:
# {'name': 'John', 'age': 25}

# %% [markdown]
# ####13. Given a dictionary my_dict = {'a': 10, 'b': 20, 'c': 30}, how can you get a default value when accessing a missing key? Write a Python program to achieve this.

# %%
my_dict = {'a': 10, 'b': 20, 'c': 30}
value = my_dict.get('d', 'Not Found')
print(value)
# Out:
# Not Found

# %% [markdown]
# ####14. Suppose you have a dictionary my_dict = {'name': 'Alice', 'age': 30}, how can you convert it into a list of tuples? Write a Python program to achieve this.

# %%
my_dict = {'name': 'Alice', 'age': 30}
list_of_tuples = list(my_dict.items())
print(list_of_tuples)
# Out:
# [('name', 'Alice'), ('age', 30)]

# %% [markdown]
# ####15. Given a dictionary my_dict = {'a': 10, 'b': 20, 'c': 30}, how can you sort it by keys? Write a Python program to achieve this.

# %%
my_dict = {'a': 10, 'b': 20, 'c': 30}
my_dict.keys()
print(my_dict)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %% [markdown]
# ####16. Suppose you have a dictionary my_dict = {'name': 'Alice', 'age': 30}, how can you delete the 'age' key using the pop() method? Write a Python program to achieve this.

# %%
my_dict = {'name': 'Alice', 'age': 30}
my_dict.pop('age')
print(my_dict)
# Out:
# {'name': 'Alice'}

# %% [markdown]
# ####17. Given a dictionary my_dict = {'x': 10, 'y': 20}, how can you check if it is empty? Write a Python program to achieve this.

# %%
my_dict = {'x': 10, 'y': 20}
if not my_dict:
  print("Dictionary is empty")
else:
  print("Dictionary is not empty")
# Out:
# Dictionary is not empty

# %% [markdown]
# ####18. Suppose you have a dictionary my_dict = {'a': 10, 'b': 20}, how can you update it with another dictionary {'c': 30, 'd': 40}? Write a Python program to achieve this.

# %%
my_dict = {'a': 10, 'b': 20}
my_dict.update({'c': 30, 'd': 40})
print(my_dict)
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40}

# %% [markdown]
# ####19. Given a dictionary my_dict = {'apple': 3, 'banana': 5}, how can you get the key associated with the maximum value? Write a Python program to achieve this.

# %%
my_dict = {'apple': 3, 'banana': 5}
max(my_dict)
# Out:
# 'banana'

# %% [markdown]
# ####20. Suppose you have a dictionary my_dict = {'a': 1, 'b': 2, 'c': 3}, how can you reverse its key-value pairs? Write a Python program to achieve this.

# %%
my_dict = {'a': 1, 'b': 2, 'c': 3}
reversed_dict = {value: key for key, value in my_dict.items()}
print(reversed_dict)
# Out:
# {1: 'a', 2: 'b', 3: 'c'}
